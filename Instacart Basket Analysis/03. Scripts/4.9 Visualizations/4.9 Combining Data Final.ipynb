# %% [markdown]
# # Combining Data

# %% [markdown]
# Content List:
# 1. Import Libraries, Create Path and Import Datasets
# 2. Prepare df's to merge
# 3. Combine order_prods_merge and Customers df's
# 4. Export new merged dataset

# %% [markdown]
# 1. Import Libraries, Create Path and Import Datasets

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#Create Path
path = r'C:\Users\ryanc\OneDrive\Documents\Data Analytics Exercises\Python\Instacart Basket Analysis'

# %%
#Import order products merged updated df
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
#Import customer df
customers = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'customers_updated_final.pkl'))

# %% [markdown]
# 2. Prepare df's to merge

# %%
#View ords_prods_merge head
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id    prices  \
# 0           1  Chocolate Sandwich Cookies        61             19  5.800781
# 1           1  Chocolate Sandwich Cookies        61             19  5.800781
# 2           1  Chocolate Sandwich Cookies        61             19  5.800781
# 3           1  Chocolate Sandwich Cookies        61             19  5.800781
# 4           1  Chocolate Sandwich Cookies        61             19  5.800781
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  ...  \
# 0   3139998      138            28          6                 11  ...
# 1   1977647      138            30          6                 17  ...
# 2    389851      709             2          0                 21  ...
# 3    652770      764             1          3                 13  ...
# 4   1813452      764             3          4                 17  ...
#
#    reordered    price_range_loc     new_busiest_days   busiest_hours  \
# ...

# %%
#View customer df head
customers.head()
# Out:
#   user_id First Name Last Name  Gender       State  Age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# Column in common  is user_id

# %%
#Check dtype
customers['user_id'].dtype
# Out:
# dtype('O')

# %%
#Check dtypes
ords_prods_merge['user_id'].dtype
# Out:
# dtype('int32')

# %%
#Change dtype
customers['user_id']=customers['user_id'].astype('int32')

# %%
#Check dtype
customers['user_id'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# 3. Combine order_prods_merge and Customers df's

# %%
#Combine df's with indicator
final_merged = ords_prods_merge.merge(customers, on = 'user_id', indicator = True)

# %%
#View all columns setting change
pd.set_option('display.max_columns', None)

# %%
#View final_merged data
final_merged.head(25)
# Out:
#     product_id                    product_name  aisle_id  department_id  \
# 0            1      Chocolate Sandwich Cookies        61             19
# 1            1      Chocolate Sandwich Cookies        61             19
# 2          907            Premium Sliced Bacon       106             12
# 3          907            Premium Sliced Bacon       106             12
# 4         1000                        Apricots        18             10
# 5         3265   Mini Seedless Watermelon Pack        32              4
# 6         4913            Table Water Crackers        78             19
# 7         6184                     Clementines        32              4
# 8         6901                     Raisin Bran       121             14
# 9         7147  Classic Baby Creamers Potatoes        83              4
# 10        7987      Hazelnut Spread with Cocoa        88             13
# 11        8048         Packaged Grape Tomatoes        32              4
# ...

# %% [markdown]
# 4. Export new merged dataset

# %%
#Export final_merge data
final_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'final_merged.pkl'))
